# %%
"Diabetes_prediction_decision_tree"

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

pd.set_option('display.max_rows', None)

# %%
my_data = pd.read_csv('diabetes.csv')
my_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
my_frame = pd.DataFrame(my_data)
my_frame.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
my_frame.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
print("Size of Data: ",my_frame.size)
print("Shape of Columns:", my_frame.shape[1])
print("Shape of Rows:", my_frame.shape[0])
# Out:
# Size of Data:  6912
# Shape of Columns: 9
# Shape of Rows: 768

# %%
my_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
my_frame.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
my_frame.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
my_frame.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
my_frame.columns.unique()
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
fig = plt.figure(figsize = (8,5))
sns.heatmap(my_frame.isnull())
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize = (8,5))
plt.hist(my_frame['Pregnancies'], bins = 5, color = 'blue')
plt.show()

# %%
fig = plt.figure(figsize = (8,5))
plt.hist(my_frame['Glucose'], bins = 5, color = 'blue')
plt.show()

# %%
fig = plt.figure(figsize = (8,5))
plt.hist(my_frame['BloodPressure'], bins = 5, color = 'blue')
plt.show()

# %%
fig = plt.figure(figsize = (8,5))
plt.hist(my_frame['Age'], bins = 5, color = 'blue')
plt.show()

# %%
fig = plt.figure(figsize = (8,5))
plt.hist(my_frame['Outcome'], bins = 5, color = 'blue')
plt.show()

# %%
fig = plt.figure(figsize = (12,8))
plt.scatter(my_frame['Pregnancies'], my_frame['Age'], color = 'purple')
plt.xlabel('Pregnanat Woman')
plt.ylabel('Age')
plt.show()

# %%
fig = plt.figure(figsize = (12,8))
plt.scatter(my_frame['SkinThickness'], my_frame['Age'], color = 'purple')
plt.xlabel('Skin Thickness')
plt.ylabel('Age')
plt.show()

# %%
fig = plt.figure(figsize = (12,8))
plt.scatter(my_frame['Glucose'], my_frame['Age'], color = 'purple')
plt.xlabel('Glucose')
plt.ylabel('Age')
plt.show()

# %%
fig = plt.figure(figsize = (12,8))
plt.scatter(my_frame['BloodPressure'], my_frame['Age'], color = 'purple')
plt.xlabel('Blood Pressure')
plt.ylabel('Age')
plt.show()

# %%
x = my_frame.drop('Outcome', axis = 1)
y = my_frame['Outcome']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 5)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_reg = LinearRegression()
linear_reg.fit(x_train, y_train)
# Out:
# LinearRegression()
